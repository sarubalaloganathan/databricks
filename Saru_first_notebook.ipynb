# %% [markdown]
# #Magic commands

# %% [markdown]
# ## Description

# %% [markdown]
# Trying out the different **magic commands** like *markdown, sql, python etc*,. we learnt in the previous session.This will help us to understand more about the commands.

# %% [markdown]
# $${\color{blue}Sarubala Loganathan}$$

# %% [markdown]
# ![](https://fpimages.withfloats.com/actual/6936e213e40c3ddda3969dd0.jpeg)
