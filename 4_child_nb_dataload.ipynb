# %%
# %py
import requests
url = "https://public.tableau.com/app/sample-data/mobile_os_usage.csv"
response = requests.get(url)


data_text = response.text

output_path = "dbfs:/Volumes/workspace/default/usage_metrics/mobile_os_usage_charu.csv"



dbutils.fs.put(output_path, data_text, overwrite=True)

# %%
dbutils.notebook.exit("All done")
